# %% [markdown]
# https://github.com/EnergieID/entsoe-py
#
#
# physical_energy_power_flows_2025 --> define the scope
# get export/import for each zone
# make heatmap
#
# client.query_physical_crossborder_allborders(country_code, start, end, export=True)
